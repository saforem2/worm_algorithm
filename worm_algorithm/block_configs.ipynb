# %% [markdown]
# # Alternate blocking schemes $1+1 = m, \,\, m \in \{ 1, 2 \}$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
from worm_simulation import WormSimulation
from bonds import Bonds
from iterated_blocking import *
from specific_heat import SpecificHeat
from pca import PrincipalComponent
from specific_heat import SpecificHeat
from count_bonds import *
import matplotlib.image as mpimg
#from matplotlib.offsetbox import AnchoredText
#import matplotlib.offsetbox as offsetbox
#from mpl_toolkits.axes_grid.inset_locator import inset_axes
#from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
#from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from scipy.signal import find_peaks_cwt

# %autoreload 2
# %matplotlib notebook
import matplotlib as mpl
label_size = 14
plt.rc('font', family='serif')
plt.rc('text', usetex=True)
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 

Tc =  2./np.log(1+np.sqrt(2))    # critical temperature

# %%
configs4_dir = '../data/configs/4_lattice/separated_data/'
configs4_files = [configs4_dir + i for i in os.listdir(configs4_dir) if 
                  i.endswith('.txt')]
configs8_dir = '../data/configs/8_lattice/separated_data/'
configs8_files = [configs8_dir + i for i in os.listdir(configs8_dir) if 
                  i.endswith('.txt')]
configs16_dir = '../data/configs/16_lattice/separated_data/'
configs16_files = [configs16_dir + i for i in os.listdir(configs16_dir) if 
                  i.endswith('.txt')]
configs32_dir = '../data/configs/32_lattice/separated_data/'
configs32_files = [configs32_dir + i for i in os.listdir(configs32_dir) if 
                  i.endswith('.txt')]

# %%
for f in configs4_files:
    block_configs(f, double_bonds_value=2)
# Out:
# Reading from ../data/configs/4_lattice/separated_data/4_config_2.3.txt
# Saving to: ../data/blocked_configs/4_lattice/double_bonds_2/2_blocked_configs_2.3.txt
#
# Reading from ../data/configs/4_lattice/separated_data/4_config_2.42.txt
# Saving to: ../data/blocked_configs/4_lattice/double_bonds_2/2_blocked_configs_2.42.txt
#
# Reading from ../data/configs/4_lattice/separated_data/4_config_2.56.txt
# Saving to: ../data/blocked_configs/4_lattice/double_bonds_2/2_blocked_configs_2.56.txt
#
# Reading from ../data/configs/4_lattice/separated_data/4_config_2.2.txt
# Saving to: ../data/blocked_configs/4_lattice/double_bonds_2/2_blocked_configs_2.2.txt
#
# Reading from ../data/configs/4_lattice/separated_data/4_config_2.0.txt
# Saving to: ../data/blocked_configs/4_lattice/double_bonds_2/2_blocked_configs_2.0.txt
#
# Reading from ../data/configs/4_lattice/separated_data/4_config_2.54.txt
# Saving to: ../data/blocked_configs/4_lattice/double_bonds_2/2_blocked_configs_2.54.txt
#
# ...

# %%
for f in configs8_files:
    block_configs(f, double_bonds_value=2)
# Out:
# Reading from ../data/configs/8_lattice/separated_data/8_config_3.3.txt
# Saving to: ../data/blocked_configs/8_lattice/double_bonds_2/4_blocked_configs_3.3.txt
#
# Reading from ../data/configs/8_lattice/separated_data/8_config_2.04.txt
# Saving to: ../data/blocked_configs/8_lattice/double_bonds_2/4_blocked_configs_2.04.txt
#
# Reading from ../data/configs/8_lattice/separated_data/8_config_2.38.txt
# Saving to: ../data/blocked_configs/8_lattice/double_bonds_2/4_blocked_configs_2.38.txt
#
# Reading from ../data/configs/8_lattice/separated_data/8_config_1.1.txt
# Saving to: ../data/blocked_configs/8_lattice/double_bonds_2/4_blocked_configs_1.1.txt
#
# Reading from ../data/configs/8_lattice/separated_data/8_config_1.0.txt
# Saving to: ../data/blocked_configs/8_lattice/double_bonds_2/4_blocked_configs_1.0.txt
#
# Reading from ../data/configs/8_lattice/separated_data/8_config_2.05.txt
# Saving to: ../data/blocked_configs/8_lattice/double_bonds_2/4_blocked_configs_2.05.txt
#
# ...

# %%
for f in configs16_files:
    block_configs(f, double_bonds_value=1)
# Out:
# Reading from ../data/configs/16_lattice/separated_data/16_config_2.48.txt
# Saving to: ../data/blocked_configs/16_lattice/double_bonds_1/8_blocked_configs_2.48.txt
#
# Reading from ../data/configs/16_lattice/separated_data/16_config_2.75.txt
# Saving to: ../data/blocked_configs/16_lattice/double_bonds_1/8_blocked_configs_2.75.txt
#
# Reading from ../data/configs/16_lattice/separated_data/16_config_1.9.txt
# Saving to: ../data/blocked_configs/16_lattice/double_bonds_1/8_blocked_configs_1.9.txt
#
# Reading from ../data/configs/16_lattice/separated_data/16_config_2.65.txt
# Saving to: ../data/blocked_configs/16_lattice/double_bonds_1/8_blocked_configs_2.65.txt
#
# Reading from ../data/configs/16_lattice/separated_data/16_config_1.8.txt
# Saving to: ../data/blocked_configs/16_lattice/double_bonds_1/8_blocked_configs_1.8.txt
#
# Reading from ../data/configs/16_lattice/separated_data/16_config_3.8.txt
# Saving to: ../data/blocked_configs/16_lattice/double_bonds_1/8_blocked_configs_3.8.txt
# ...

# %%
for f in configs32_files:
    block_configs(f, double_bonds_value=1)
# Out:
# Reading from ../data/configs/32_lattice/separated_data/32_config_2.4.txt
# Saving to: ../data/blocked_configs/32_lattice/double_bonds_1/16_blocked_configs_2.4.txt
#
# Reading from ../data/configs/32_lattice/separated_data/32_config_2.5.txt
# Saving to: ../data/blocked_configs/32_lattice/double_bonds_1/16_blocked_configs_2.5.txt
#
# Reading from ../data/configs/32_lattice/separated_data/32_config_2.75.txt

# %%
config8_0 = pd.read_csv(configs8_files[0], header=None, engine='c', delim_whitespace=True, index_col=0).values

# %%
temp8_0 = configs8_files[0].split('/')[-1].split('_')[-1].rstrip('.txt')
temp8_0
# Out:
# '3.3'

# %%
bconfig8_0 = _block_config(config8_0[0], double_bonds_value=1)

# %%
bconfig8_0.shape
# Out:
# (64,)

# %%
fig, ax = plt.subplots()
ax.imshow(config8_0[0].reshape(16,16), cmap="Greys")
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig, ax = plt.subplots()
ax.imshow(bconfig8_0.reshape(8,8), cmap="Greys")
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
_block_conf
# Out:
# Reading from ../data/configs/8_lattice/separated_data/8_config_3.3.txt
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-5-a4c2813db772> in <module>()
#       1 for f in configs8_files:
# ----> 2     block_configs(f, double_bonds_value=1)
#
# ~/worm_algorithm/worm_algorithm/iterated_blocking.py in block_configs(config_file, double_bonds_value, out_dir)
#     100             #  out_dir = ("../data/iterated_blocking/"
#     101             #             + "{}_lattice/blocked_{}".format(L, L_blocked))
# --> 102         save_blocked_configs(blocked_configs, temp, out_dir=out_dir)
#     103     except IOError:
#     104         print("Unable to read from: {}".format(config_file))
#
# ~/worm_algorithm/worm_algorithm/iterated_blocking.py in save_blocked_configs(configs, temperature, out_dir)
# ...
